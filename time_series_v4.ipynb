# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Елена, привет!👋</b>
#
# Меня зовут Кирилл Васильев, мы уже встречались на проекте «Линейные модели». Рад снова быть ревьюером твоей работы!
#
# Я буду оставлять комментарии в твоем проекте. Пожалуйста, не удаляй их, они могут быть полезны в случае повторной проверки.
#
# Свои комментарии я буду обозначать <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным. Здесь же я могу давать советы и предложения.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# <br/>
# <div class="alert alert-info">
# Рекомендую для твоих комментариев использовать синий или любой другой цветной фон. Я постараюсь ничего не пропустить, но если комментарии будут выделены, то это мне очень поможет!
# </div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самостоятельно найти и исправить ее. На реальной работе твой руководитель будет поступать также. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет. Кажется вы, ревьюеры, действительно выписываете куда-то имена заинтересовавших вас студентов. Проверяющие редко повторяются, и вдвойне приятно, что вы нас тоже помните.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Привет) А у нас в CRM-ке все видно :)
# </div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#План-проекта" data-toc-modified-id="План-проекта-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>План проекта</a></span></li><li><span><a href="#Загрузка-библиотек" data-toc-modified-id="Загрузка-библиотек-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Загрузка библиотек</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Загрузка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных-из-файла" data-toc-modified-id="Загрузка-данных-из-файла-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Загрузка данных из файла</a></span></li><li><span><a href="#Ресемплирование-данных" data-toc-modified-id="Ресемплирование-данных-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Ресемплирование данных</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Исследование-файла-с-часовым-интервалом" data-toc-modified-id="Исследование-файла-с-часовым-интервалом-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Исследование файла с часовым интервалом</a></span></li><li><span><a href="#Исследование-файла-с-ежедневным-интервалом" data-toc-modified-id="Исследование-файла-с-ежедневным-интервалом-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Исследование файла с ежедневным интервалом</a></span></li><li><span><a href="#Дополнительные-параметры-нашего-временного-ряда" data-toc-modified-id="Дополнительные-параметры-нашего-временного-ряда-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Дополнительные параметры нашего временного ряда</a></span></li></ul></li><li><span><a href="#Подбор-и-обучение-моделей" data-toc-modified-id="Подбор-и-обучение-моделей-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Подбор и обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Модель-Prophet" data-toc-modified-id="Модель-Prophet-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Модель Prophet</a></span></li><li><span><a href="#Модель-Линейной-регрессии" data-toc-modified-id="Модель-Линейной-регрессии-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Модель Линейной регрессии</a></span></li><li><span><a href="#Модель-DecisionTreeRegressor" data-toc-modified-id="Модель-DecisionTreeRegressor-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Модель DecisionTreeRegressor</a></span></li><li><span><a href="#Модель-XGBRegressor" data-toc-modified-id="Модель-XGBRegressor-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Модель XGBRegressor</a></span></li><li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Сравнение моделей</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Временные ряды. Проект

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Построим модель для такого предсказания.
# Значение метрики RMSE на тестовой выборке должно быть не больше 48.
#
# Данные лежат в файле `datasets/taxi.csv`
# Количество заказов находится в столбце `num_orders` (от англ. number of orders, «число заказов»).

# %% [markdown]
# ## План проекта

# %% [markdown]
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.

# %% [markdown]
# ## Загрузка библиотек

# %%
# обновляю библиотеку

# !pip install --upgrade scikit-learn -q

# %%
# устанавливаю библиотеку

# !pip install xgboost -q

# %%
# устанавливаю библиотеку

# !pip install prophet -q

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import statsmodels.api as sm
import xgboost as xgb

import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.tsa.stattools as ts


from prophet import Prophet

from statsmodels.graphics import tsaplots
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tools.eval_measures import rmse

from sklearn.model_selection import (train_test_split,
                                     TimeSeriesSplit,
                                     cross_val_score,
                                    GridSearchCV)

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import root_mean_squared_error

from xgboost import XGBRegressor

RANDOM_STATE = 42

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично по описанию и импортам.
# </div>

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# ### Загрузка данных из файла

# %% [markdown]
# Сначала просто прочтем данные:
# ![image.png](attachment:image.png)
#
# Теперь сразу при загрузке обработаем колонку с датой, превратив ее в индексы.

# %%
try:
    data = pd.read_csv('C:\\Users\\ElenaB\\Projects\\pj_16\\taxi.csv', index_col=[0], parse_dates=[0])
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/taxi.csv', index_col=[0], parse_dates=[0])

data.info()    
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Данные получены верно, даты обработаны, мы их переместили в индекс. Полет нормальный :)
# </div>

# %%
# проверим наши данные на хронологию

data.sort_index(inplace=True)
print(data.index.is_monotonic)
# Out:
# True

# %% [markdown]
# Данные отсортированы корректно. Исходя из первых пяти строк, сейчас данные зафиксированы для каждых 10 минут.

# %% [markdown]
# ### Ресемплирование данных

# %% [markdown]
# Необходимо произвести ресемплирование данных к 1 часу.
#
# Поскольку данные снимались каждые десять минут, можно предположить, что это количество новых, необработанных заказов такси. Поэтому после ресемплирования данные будем суммировать.

# %%
data_l = data.resample('1H').sum() 
data_l.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4416 entries, 2018-03-01 00:00:00 to 2018-08-31 23:00:00
# Freq: H
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  4416 non-null   int64
# dtypes: int64(1)
# memory usage: 69.0 KB

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Все так, суммируем по условию задачи.
# </div>

# %% [markdown]
# Наши данные теперь обработаны за период с 0 часов 1 марта 2018 года по 23 часа ровно 31 августа 2018 года.
#
# Построим общий график данных.

# %%
plt.rcParams['figure.figsize'] = [12, 8]
data_l.plot()
plt.title('Временной ряд заказов такси')
plt.xlabel('Момент времени')
plt.ylabel('Количество заказов')
plt.show()

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Исследование файла с часовым интервалом

# %% [markdown]
# Воспользуемся методом библиотеки statsmodels, и посмотрим на компоненты нашего временного ряда.

# %%
decomposed = sm.tsa.seasonal_decompose(data_l)

# %%
decomposed.plot()
plt.show()

# %% [markdown]
# В наблюдаемых данных есть тренд на увеличение среднего значения заказов. А также есть сезонность. Причем, судя по частоте пиков, с очень небольшим периодом. Попробуем сузить интервал последовательно до месяца, недели, дня, чтобы определить интервал сезонности.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Да, при ресемплировании по часу сезонность (недельная и суточная) у нас убежала в тренд. Чтобы посмотреть на сезонность внимательнее, нужно здесь брать промежуток значений меньше - для суточной сезонности, а также делать дополнительное ресемплирование по дням − для недельной.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Я еще из теории в уроке не смогла понять, как правильно строить вот эти графики на "уменьшенном" интервале. Есть там задачка одна, когда decomposed мы берем для всего датафрейма, а график строим на кусочек компоненты.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Ну пути у нас два: растягивать график (смотреть за меньший промежуток) или делать другое ресемплирование. Здесь пригодятся оба.
# </div>

# %%
plt.rcParams['figure.figsize'] = [12, 4]
decomposed.seasonal['2018-06':'2018-07'].plot()
plt.xlabel('Момент времени')
plt.show()

# %%
decomposed.seasonal['2018-06-22':'2018-06-28'].plot()
plt.xlabel('Момент времени')
plt.show()

# %%
decomposed.seasonal['2018-06-22':'2018-06-23'].plot()
plt.xlabel('Момент времени')
plt.show()

# %% [markdown]
# Сезонность получается с однодневным интервалом: на 6:00 приходится минимум числа заказов, на 0:00 приходится максимум.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Верно.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Продублирую:
#
# Важно также изучить недельную сезонность. Удобнее всего ее увидеть, если сделать дополнительное ресемплирование (сохраняем в другую переменную, так как дальше в проекте будем работать с ресемплированием по часам и важно его не потерять) по дням.
#
# При ресемплировании по часам недельная сезонность уходит в тренд декомпозиции.
#
# ***
#
# ***
#
# По «остаткам» или шуму. Нужно посмотреть, на всем ли протяжении доля остатков одинаковая? Если если «остатков» к концу графика больше, значит в тестовую выборку попадет чуть больше данных, которые сложно объяснить и на которых модели будет сложнее предсказывать. Поэтому относительно большая (по сравнению с другими задачами машинного обучения) разница между метриками при обучении и исследовании, и между тестовой выборкой, не обязательно будет объясняться только переобучением модели.

# %% [markdown]
# ### Исследование файла с ежедневным интервалом

# %%
# сделаем ресеплирование

data_day = data.resample('1D').sum() 
data_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 184 entries, 2018-03-01 to 2018-08-31
# Freq: D
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  184 non-null    int64
# dtypes: int64(1)
# memory usage: 2.9 KB

# %%
# обработаем и построим график

decomposed_day = sm.tsa.seasonal_decompose(data_day)

plt.rcParams['figure.figsize'] = [12, 8]
decomposed_day.plot()
plt.show()

# %% [markdown]
# Судя по виду сезонной компоненты, у нас действительно есть и недельная зависимость.
#
# Относительно шума - пожалуй, к последним датам увеличилась дисперсия шума, но не количество точек.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Может, я опять неверно понимаю? Берем данные, ресемплированные на один период, а график показывает наличие сезонности для бОльшего периода?

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Да, все так. Сейчас выше видим «М»-образный график. Это график недельной активности людей, он примерно всегда будет таким. Значит записываем, что у нас недельная сезонность.
# </div>

# %% [markdown]
# ### Дополнительные параметры нашего временного ряда

# %%
#plt.rcParams['figure.figsize'] = [12, 8]
data_l['mean'] = data_l['num_orders'].rolling(24).mean()
data_l['std'] = data_l['num_orders'].rolling(24).std()
data_l.plot()
plt.show()

# %%
# посмотрим на актокорреляцию с суточным шагом

plt.rcParams['figure.figsize'] = [12, 4]
fig = tsaplots.plot_acf(data_l['num_orders'], lags=24)
plt.ylim(-.1, 1.1)
plt.show()

# %%
# посмотрим на автокорреляцию с недельным лагом

fig = tsaplots.plot_acf(data_l['num_orders'], lags=168)
plt.ylim(-.1, 1.1)
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Отлично, что смотрим на автокорреляцию, но здесь важно взять побольше диапазон, чтобы увидеть все интересное. У нас же корреляция может быть по суткам (тогда коррелирующий лаг будет 24-й , а тажке по неделе: 168-й.
#
# Функция показывает, как признак коррелирует с предыдущими. Область синей заливки обозначает порог статистической значимости (если значение внутри, корреляция уже не заслуживает доверия. Статзначимость вычисляется по тесту Стьюдента).
# </div>

# %% [markdown]
# При построении графика автокорреляции предполагается следующее: если остатки независимы, то автокорреляция будет близка к нулю. Вопрос в том, что можно считать достаточно близким к нулю. В общем, между лагами, кратными 24 часам, значение автокорреляции находится на уровне 0.3.
#
# И да, между 0 и 168 лагом тоже весьма высокая автокорреляция.

# %%
fig_w = tsaplots.plot_acf(data_day['num_orders'], lags=28)
plt.ylim(-.1, 1.1)
plt.show()

# %% [markdown]
# Этот вариант графика показывает высокую корреляцию между дневными показателями (это мы знаем), и чуть большие - между недельными показателями. Но при этом область статистической значимости перекрывает значения автокорреляции, дальше, чем на 2 недели, а значит, эти показатели недостоверны.

# %%
# код ревьюера
fig = tsaplots.plot_acf(data_l['num_orders'], lags=190)
plt.ylim(-.1, 1.1)
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> А почему тогда лаг 190? Не 192 (это 24+168) и не 168? Хм, наверное, чтобы было больше, чем что-то кратное 24 часам.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 на графике − чисто для наглядности, чтобы показать, что после недельного 168-го идет спад.
# </div>

# %% [markdown]
# ## Подбор и обучение моделей

# %% [markdown]
# Для предсказания данных во временных рядах можно использовать как общие модели машинного обучения, так и специализированные библиотеки. Попробуем воспользоваться для предсказания: моделью Линейной регрессии, моделью градиентного бустинга, библиотекой Prophet.
#
# В качестве тестовых данных нам необходимо использовать 10% всей выборки. И RMSE нашей модели должна быть меньше 48.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отличный подход.
# </div>

# %% [markdown]
# ### Модель Prophet

# %% [markdown]
# Для этой модели важны названия столбцов с данными. Поэтому придется произвести некоторые манипуляции.

# %%
# возьмем копию исходного датафрейма

data_pr = data.resample('1H').sum().reset_index().copy()
data_pr.head()
# Out:
#              datetime  num_orders
# 0 2018-03-01 00:00:00         124
# 1 2018-03-01 01:00:00          85
# 2 2018-03-01 02:00:00          71
# 3 2018-03-01 03:00:00          66
# 4 2018-03-01 04:00:00          43

# %%
# заменим названия столбцов

data_pr.columns = ['ds','y']

# %%
# разделим данные на выборки

TEST_SIZE = int(0.1 * data_pr.shape[0])

train_pr = data_pr.iloc[:-TEST_SIZE] 
test_pr = data_pr.iloc[-TEST_SIZE:]

# %%
# инициализируем и обучим модель

model_pr = Prophet(daily_seasonality=True, weekly_seasonality=True, seasonality_mode='multiplicative')
model_pr.fit(train_pr)
# Out:
# 11:42:11 - cmdstanpy - INFO - Chain [1] start processing
# 11:42:12 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Здесь также не стоит забывать о сезонностях: можно явно прописать их в аргументы модели.
#
# `model_pr = Prophet(daily_seasonality=True, weekly_seasonality=True, seasonality_mode='multiplicative')`
#
# У нас есть дневная и недельная сезонности, они накладываются друг на друга.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Ох, я не настолько разобралась в этой библиотеке. Как обезьянка, смогла повторить простейшие шаги, но немного запуталась в их инструкциях. Тем более, что с недельной корреляцией все не так просто.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Ну вот объясняю) Есть такие опции. Без них профет тоже завелся и что-то хорошее вывел, так что для начала и твой подход ок.
# </div>

# %%
# создадим датафрейс с предсказаниями модели

future_pr = model_pr.make_future_dataframe(periods=TEST_SIZE, freq='h')
forecast = model_pr.predict(future_pr)
forecast.head()
# Out:
#                    ds      trend  yhat_lower  yhat_upper  trend_lower  \
# 0 2018-03-01 00:00:00  55.326822   46.093729  110.344416    55.326822
# 1 2018-03-01 01:00:00  55.332766   47.724461  109.539959    55.332766
# 2 2018-03-01 02:00:00  55.338709   48.636365  110.408851    55.338709
# 3 2018-03-01 03:00:00  55.344653   37.992982   98.092119    55.344653
# 4 2018-03-01 04:00:00  55.350597   20.362094   81.429753    55.350597
#
#    trend_upper     daily  daily_lower  daily_upper  multiplicative_terms  \
# 0    55.326822  0.396700     0.396700     0.396700              0.417428
# 1    55.332766  0.418536     0.418536     0.418536              0.432647
# 2    55.338709  0.392821     0.392821     0.392821              0.400020
# 3    55.344653  0.234375     0.234375     0.234375              0.234493
# 4    55.350597 -0.082918    -0.082918    -0.082918             -0.089921
#
#    multiplicative_terms_lower  multiplicative_terms_upper    weekly  \
# ...

# %%
# соберем данные из предсказния в датафрейм и посчитаем метрику

prophet_pred = pd.DataFrame({"Date":forecast['ds'], 
                             "Pred":forecast["yhat"]})

prophet_pred = prophet_pred.set_index("Date")

prophet_rmse_error_train = rmse(train_pr['y'], prophet_pred[:-TEST_SIZE]['Pred'])

prophet_rmse_error_test = rmse(test_pr['y'], prophet_pred[-TEST_SIZE:]['Pred'])

print("Train")
print(f'RMSE Error: {prophet_rmse_error_train}')

print("Test")
print(f'RMSE Error: {prophet_rmse_error_test}')
# Out:
# Train
# RMSE Error: 24.48871142374238
# Test
# RMSE Error: 44.61165963257486

# %% [markdown]
#  <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Ух)) Я долго не мог понять, как так вышло, искал ошибку в коде профета.
#
# ```
# prophet_rmse_error_train = rmse(test_pr['y'], prophet_pred[-TEST_SIZE:]['Pred'])
#
# prophet_rmse_error_test = rmse(train_pr['y'], prophet_pred[:-TEST_SIZE]['Pred'])
#
# ```
# Cмотри, качество тренировочной выборки ты сохраняешь в тестовую, а качество тестовой − в тренировочную. То есть, конечно же качество на тренировочной будет лучше.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> А мы точно такие данные ожидали? Что на трейне будет получше, на тесте - похуже? Потому что тестовые данные чуть более "замусорены".

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Именно. Поэтому RMSE на тесте сильно выше - то есть, модель ошибается больше.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# По общему качеству можно попробовать чуть улучшить:
#
# * укажем сезонности еще на входе в модель в качестве аргументов
# * можно посмотреть, где модель лучше предсказала. Возможно, yhat_upper (верхняя граница д.и.предсказания) будет иметь лучшее качество.
#
# </div>

# %%
# построим общий график предсказания

model_pr.plot(forecast, figsize=(16, 6))
plt.show()

# %%
# 

plt.figure(figsize=(16,5))

prophet_pred[-TEST_SIZE:]['Pred'].plot(fontsize=14)
test_pr = test_pr.set_index(['ds'])
test_pr['y'].plot(fontsize=14)
plt.legend(loc = 'best', framealpha = 1)
plt.show()

# %%
# посмотрим на компоненты предсказания

fig = model_pr.plot_components(forecast)

# %% [markdown]
# Модель Prophet увидела в данных и недельную сезонность, и дневную. Пики минимального и максимального количества заказов для ежедневного цикла совпадают с общим анализом данных из statsmodel.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 В целом отлично и корректно. Нужно только поправить по коду метрик.
# </div>

# %% [markdown]
# ### Модель Линейной регрессии

# %% [markdown]
# Все признаки нам нужно будет подготовить самим, но зато можно подобрать количество колонок с лагом. И разделить выборку.

# %%
# добавим признаки

data_l['day'] = data_l.index.day
data_l['dayofweek'] = data_l.index.dayofweek
data_l['hour'] = data_l.index.hour
    
for lag in range(1, 169):
    data_l['lag_{}'.format(lag)] = data_l['num_orders'].shift(lag)

data_l['rolling_mean'] = data_l['num_orders'].shift().rolling(1).mean()
data_l = data_l.drop(['mean'], axis=1)

data_l.sample(3)
# Out:
#                      num_orders        std  day  dayofweek  hour  lag_1  \
# datetime
# 2018-07-09 19:00:00          76  30.822041    9          0    19   78.0
# 2018-08-30 06:00:00          13  57.425172   30          3     6   56.0
# 2018-07-01 06:00:00          38  28.068240    1          6     6   59.0
#
#                      lag_2  lag_3  lag_4  lag_5  ...  lag_160  lag_161  \
# datetime                                         ...
# 2018-07-09 19:00:00   98.0   93.0  122.0   78.0  ...    104.0    103.0
# 2018-08-30 06:00:00  186.0  193.0  232.0  217.0  ...    112.0     88.0
# 2018-07-01 06:00:00  108.0   89.0  100.0   84.0  ...    107.0     42.0
#
#                      lag_162  lag_163  lag_164  lag_165  lag_166  lag_167  \
# datetime
# 2018-07-09 19:00:00    121.0    149.0    121.0     71.0     83.0     89.0
# 2018-08-30 06:00:00    143.0    124.0    150.0    135.0    113.0     38.0
# 2018-07-01 06:00:00     74.0     51.0     60.0     94.0     64.0     22.0
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Tеперь забыли удалить скользящее среднее, которое создавали для аналитики выше. У тебя отдельно есть признак mean и rolling_mean. Во втором случае в функции мы его создаем с учетом лага .shift(), в первом − без учета, поэтому в первом в него попадает наш таргет. Модель вполне способна восстановить таргет по среднему и всем входящим в него элементам.
#
# Важно удалить mean.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Я догадывалась, что где-то допустила утечку. Но не понимала, где именно. Я даже не сразу сообразила, где я их - эти признаки - добавила. Кажется, стоило или аналитику делать на другом (копии) датасете, или модели обучать на другом.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Можем ли «поймать» годовую сезонность? Важен ли месяц?
#
# Наши календарные признаки подчеркивают сезонность. Относительно сезонности признаки идут на один уровень ниже. Если у нас суточная сезонность, то логично создавать признак часа (час одного дня похож на тот же час другого), если недельная - день недели.
#
# Месяц нам был бы нужен, если бы была годовая сезонность. Что же касается тренда, то из признака месяца модель его не усвоит.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправляю. Это была не совсем очевидная штука для человека, впервые изучающего временные ряды.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Так и есть, меня в свое время тоже не с первого раза убедили в том, что человек воспринимает ряд иначе, чем машина :)
#
# Можно провести аналогию с инопланетянином, который не знает, у нас будет 12 или 1500 месяцев в году. Если показать признак от 3 до 7 месяца, то он ему ничего не даст.
# </div>

# %%
# определим функцию для тестирования количества признаков в модели

# def model_preds (data_x, model):
    
#     train, test = train_test_split(data_x, shuffle=False, test_size=0.1, random_state=RANDOM_STATE)
#     train = train.dropna()
    
#     X_train = train.drop(['num_orders'], axis=1)
#     y_train = train['num_orders']
#     X_test = test.drop(['num_orders'], axis=1)
#     y_test = test['num_orders']

#     model.fit(X_train, y_train)

#     pred = model.predict(X_test)

#     rmse = root_mean_squared_error(pred, y_test)
    
#     tscv = TimeSeriesSplit(n_splits=5)
#     scores = cross_val_score(estimator=model, cv=tscv, X=X_train, 
#                              y=y_train, scoring='neg_root_mean_squared_error').mean()
    
#     return rmse, scores, pred

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Тестовую выборку до тестирования в проекте не трогаем, если сравниваем несколько моделей по качеству. Иначе оценка тестовой выборки будет уже смещенной и завышенной. Важно соблюсти принцип научного эксперимента и исключить субъективность. Нам от тестовой выборки нужно лишь узнать, какое качество ожидаем увидеть после внедрения модели.
#
# Лучшую же модель можно спокойно подобрать по кросс-валидации.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Хм, убираем из функции кусочек, связанный с предиктом по X test. И подбор лагов убираем. И разделение на выборки тоже можно вынести из функции. Так это все надо переделать. Я с подбором числа лагов возилась потому, что, во-первых, студентов просят побольше функций впихивать, во-вторых, в теории спринта утверждали, что это важный момент. Тогда стоит один раз разделить выборку, один раз выделить признаки и лаги, и попытаться победить грид-серч, который у меня что-то заупрямился.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Про подбор лагов: не нужно решать задачу про дважды два методом Монте-Карло. Если можем аналитически (посмотрев на графики) понять, сколько лагов подавать оптимально, то правильнее будет не делать перебор. Тем более, в таких неэффективных диапазонах.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
#
# Лаги, конечно, можно подбирать в принципе, но при нашем знании, что в данных будет суточная и недельная сезонности,
# и обе сильные, я бы взял 168 лагов, опираясь на график автокорреляции.
#
# Подбор лагов ниже я бы убрал из проекта.
#
# ***
#
# Если при разделении на выборки ничего не перемешиваем, то RANDOM_STATE указывать не имеет смысла.
# </div>

# %%
# разделим выборку

train, test = train_test_split(data_l, shuffle=False, test_size=0.1)
train = train.dropna()
    
X_train = train.drop(['num_orders'], axis=1)
y_train = train['num_orders']
X_test = test.drop(['num_orders'], axis=1)
y_test = test['num_orders']

# %%
train
# Out:
#                      num_orders        std  day  dayofweek  hour  lag_1  \
# datetime
# 2018-03-08 00:00:00         143  36.452073    8          3     0   94.0
# 2018-03-08 01:00:00          78  34.417487    8          3     1  143.0
# 2018-03-08 02:00:00          65  33.557543    8          3     2   78.0
# 2018-03-08 03:00:00          68  33.571037    8          3     3   65.0
# 2018-03-08 04:00:00          60  33.487803    8          3     4   68.0
# ...                         ...        ...  ...        ...   ...    ...
# 2018-08-13 09:00:00         137  79.879393   13          0     9   91.0
# 2018-08-13 10:00:00         156  79.768279   13          0    10  137.0
# 2018-08-13 11:00:00         144  78.868251   13          0    11  156.0
# 2018-08-13 12:00:00          92  79.408639   13          0    12  144.0
# 2018-08-13 13:00:00         119  79.419075   13          0    13   92.0
#
#                      lag_2  lag_3  lag_4  lag_5  ...  lag_160  lag_161  \
# ...

# %%
# обозначим нашу кроссвалидацию

tscv = TimeSeriesSplit(n_splits=5)

# %%
# инициируем модель

m_lin = LinearRegression()

# %%
# убрала строки с прошлой версией, где функциями обрабатывала модель

#     print('Размер лага [{}]'.format(max_lag), 
#           "Значение RMSE на тестовой выборке:" , round((model_preds(data_l, m_lin)[0]), 2),
#          "Средняя ошибка на кросс-валидации:", round(abs(model_preds(data_l, m_lin)[1]), 2))

# %%
# обозначим гиперпараметры для поиска

param_lin = {'n_jobs': [-1, 1]}

# произведем поиск для модели Линейной регрессии

grid_lin = GridSearchCV(
            estimator=m_lin, 
            param_grid=param_lin, 
            cv=tscv,
            scoring='neg_root_mean_squared_error', 
            n_jobs=-1)

grid_lin.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', grid_lin.best_estimator_)
print('Метрика лучшей модели на тренировочной выборке:', abs(grid_lin.best_score_))
# Out:
# Лучшая модель и её параметры:
#
#  LinearRegression(n_jobs=-1)
# Метрика лучшей модели на тренировочной выборке: 22.46128206326649

# %% [markdown]
# Чуть лучше RMSE, чем у Prophet на тренировочной выборке. Иногда простой путь - самый лучший.

# %% [markdown]
# ~~В общем, логично. При сезонности в 1 день, ожидаемо, что при лаге в 23 часа данные практически сойдутся.~~

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 А как они сойдутся при 168 лаге )))
# </div>

# %% [markdown]
# ### Модель DecisionTreeRegressor

# %% [markdown]
# Можно воспользоваться нашими функциями для линейной модели, и посмотреть на значения.

# %%
# m_dtr = DecisionTreeRegressor()

# data_dtr =  data.resample('1H').sum()

# for max_lag in range (1, 23):
#     make_features(data_dtr, max_lag, 1)
#     model_preds(data_dtr, m_dtr)
    
#     print('Размер лага [{}]'.format(max_lag), 
#           "Значение RMSE на тестовой выборке:" , round((model_preds(data_dtr, m_dtr)[0]), 2),
#          "Средняя ошибка на кросс-валидации:", round(abs(model_preds(data_dtr, m_dtr)[1]), 2))

# %%
# инициируем модель

m_dtr = DecisionTreeRegressor()


# подбираем гиперпараметры

param_dtr = [{'min_samples_split': range (2, 10),
              'min_samples_leaf': range (2, 10)}]

# %%
# произведем поиск

grid_dtr = GridSearchCV(
            estimator=m_dtr, 
            param_grid=param_dtr, 
            cv=tscv,
            scoring='neg_root_mean_squared_error', 
            n_jobs=-1)

grid_dtr.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', grid_dtr.best_estimator_)
print('Метрика лучшей модели на тренировочной выборке:', abs(grid_dtr.best_score_))
# Out:
# Лучшая модель и её параметры:
#
#  DecisionTreeRegressor(min_samples_leaf=9, min_samples_split=8)
# Метрика лучшей модели на тренировочной выборке: 28.809697319936856

# %% [markdown]
# В целом, модель показывает себя ~~гораздо~~ несколько хуже.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Есть такое.
# </div>

# %% [markdown]
# ### Модель XGBRegressor

# %%
# m_xgb = XGBRegressor()

# data_xgb =  data.resample('1H').sum()

# for max_lag in range (1, 23):
#     make_features(data_xgb, max_lag, 1)
#     model_preds(data_xgb, m_xgb)
    
#     print('Размер лага [{}]'.format(max_lag), 
#           "Значение RMSE на тестовой выборке:" , round((model_preds(data_xgb, m_xgb)[0]), 2),
#          "Средняя ошибка на кросс-валидации:", round(abs(model_preds(data_xgb, m_xgb)[1]), 2))

# %%
# инициируем модель

m_xgb = XGBRegressor()


# обозначичм гиперпараметры

param_xgb = {'booster': ['gbtree', 'gblinear']}

# %%
# произведем поиск

grid_xgb = GridSearchCV(
            estimator=m_xgb, 
            param_grid=param_xgb, 
            cv=tscv,
            scoring='neg_root_mean_squared_error', 
            n_jobs=-1)

grid_xgb.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', grid_xgb.best_estimator_)
print('Метрика лучшей модели на тренировочной выборке:', abs(grid_xgb.best_score_))
# Out:
# Лучшая модель и её параметры:
#
#  XGBRegressor(base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)
# Метрика лучшей модели на тренировочной выборке: 23.870488225033405

# %% [markdown]
# ~~Начиная с 4 и более колонок со смещениями, модель предсказывает примерно одинаково.~~

# %% [markdown]
# ### Сравнение моделей

# %%
# test_pr['lin_preds'] = model_preds(data_l, m_lin)[2][:-1]
# test_pr['dtr_preds'] = model_preds(data_dtr, m_dtr)[2][:-1]
# test_pr['xgb_preds'] = model_preds(data_xgb, m_xgb)[2][:-1]

# %% [markdown]
# В точки зрения наименьшего значения метрики среди протестированных моделей лучшей оказалась модель Линейно регрессии.

# %%
models = pd.DataFrame(data=[['prophet', prophet_rmse_error_train],
                            ['m_lin', abs(grid_lin.best_score_)], 
                            ['m_dtr', abs(grid_dtr.best_score_)],
                            ['m_xgb', abs(grid_xgb.best_score_)]], 
                      columns=['models', 'RMSE_train'])

models
# Out:
#     models  RMSE_train
# 0  prophet   24.488711
# 1    m_lin   22.461282
# 2    m_dtr   28.809697
# 3    m_xgb   23.870488

# %%
#

pred_lin = grid_lin.best_estimator_.predict(X_test)

rmse_lin = root_mean_squared_error(y_test, pred_lin)

pred_dtr = grid_dtr.best_estimator_.predict(X_test)

rmse_dtr = root_mean_squared_error(y_test, pred_dtr)

pred_xgb = grid_xgb.best_estimator_.predict(X_test)

rmse_xgb = root_mean_squared_error(y_test, pred_xgb)

# %%
#

models['RMSE_test'] = [prophet_rmse_error_test, rmse_lin, rmse_dtr, rmse_xgb]

models
# Out:
#     models  RMSE_train  RMSE_test
# 0  prophet   24.488711  44.611660
# 1    m_lin   22.461282  34.128954
# 2    m_dtr   28.809697  44.978512
# 3    m_xgb   23.870488  41.247943

# %% [markdown]
# Добавим проверку модели на адекватность - пусть у нас будут предсказания, равные предыдущему значению.

# %%
#

pred_previous = y_test.shift()
pred_previous.iloc[0] = y_train.iloc[-1]
rmse_base =  root_mean_squared_error(y_test, pred_previous)
print("RMSE baseline модели:", round(rmse_base, 3))
# Out:
# RMSE baseline модели: 58.856

# %%
# Объединим предсказания

predictions = pd.DataFrame({
    'y_test': y_test,
    'pred_prev': pred_previous,
    'lin_preds': pred_lin.astype('int'),
    'dtr_preds': pred_dtr.astype('int'),
    'xgb_preds': pred_xgb.astype('int')
}, index= y_test.index)

predictions
# Out:
#                      y_test  pred_prev  lin_preds  dtr_preds  xgb_preds
# datetime
# 2018-08-13 14:00:00     102      119.0        132         81         80
# 2018-08-13 15:00:00     175      102.0        140        128        132
# 2018-08-13 16:00:00     144      175.0        199        166        172
# 2018-08-13 17:00:00     152      144.0        145        139        120
# 2018-08-13 18:00:00     104      152.0        103        100         90
# ...                     ...        ...        ...        ...        ...
# 2018-08-31 19:00:00     136      207.0        130        175        128
# 2018-08-31 20:00:00     154      136.0        172        166        160
# 2018-08-31 21:00:00     159      154.0        188        177        152
# 2018-08-31 22:00:00     223      159.0        221        177        197
# 2018-08-31 23:00:00     205      223.0        210        177        204
#
# [442 rows x 5 columns]

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.0</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> У меня не совпала размерность данных. В результате из модели Пророка вышло 441 строка. А в результате моделей регрессоров - 442 строки. Какая-то проблема округления?

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Нет, дело не в этом. И там, и там берем по индексам, ничего нигде не округляем.
#
# Дело в том, что здесь мы моделями предсказываем значение для каждой строки, основываясь на фичах из предыдущей. Зная состояние данных на текущий час времени, мы предсказываем следующей час, верно? Тогда для одного из значений у нас из-за смещения предсказаний не будет. Вот оно и потерялось.
#
# Профет же не относится к ML, он просто моделирует график ряда, учитывая все колебания (берет сезонности и накладывает их друг на друга, потом берет тренд итд). В этом его сила для устойчивых и стационарных рядов, но в этом и слабость для ситуация типа нашего, где в августе будет ускорение тренда. Тогда модели, учитывающие скользящее среднее (еще есть экспоненциальное сглаживание, например), будут работать лучше.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Интересно. Я-то хотела просто объединить все предсказания, чтобы порисовать графики сравнения. А оно вон как оказалось. И опять все не так просто - в предсказаниях XGBoost оказались NaN-ы. И при перезапусках тетради Линейная регрессия начинают слишком хорошо предсказывать данные. Если при первом запуске она имеет метрику 22 и 34, то при последующих - метрика стремится к нулю.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Да, пропустили утечку. У нас всегда качество модели будет неидеальным. Если оно идеальное − ищим утечку либо признаков, либо таргета.
#
# (признаков - это когда в тестовую выборку попадают строки обучающей. Утечка таргета − это когда в фичи протекает таргет, как сейчас в mean).
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> После удаления mean и NaN-ы пропали. Добавила их в итоговую табличку.

# %%
plt.rcParams['figure.figsize'] = [12, 8]
predictions[['y_test', 'pred_prev']].plot()
plt.title("Сравнение предсказаний между различными моделями");

# %%
predictions[['y_test', 'lin_preds']].plot()
plt.title("Сравнение предсказаний между различными моделями");

# %%
predictions[['y_test', 'dtr_preds']].plot()
plt.title("Сравнение предсказаний между различными моделями");

# %%
predictions[['y_test', 'xgb_preds']].plot()
plt.title("Сравнение предсказаний между различными моделями");

# %% [markdown]
# В целом, все модели смогли уловить ключевые зависимости временного ряда. Но наибольшим отклонением от реальных данных обладает модель DecisionTreeRegressor. А вот линейная модель показала себя наилучшим образом.
#
# ПОлагаю, причина успеха линейной модели - наличие в данных сезонных зависимостей по дням и неделям.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.0</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Я понимаю, что проект полусырой. Я не пробовала разобраться с моделями ARIMA. Я не смогла разобраться с GridSearch. У меня были проблемы с функциями, данными, графиками. Я бы хотела получить направления, в котором нужно улучшить проект. Пока у меня слишком сумбурно все.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Давай тогда сконцентрируемся на учебном минимуме и прояснении базы − доработаем проект в частях, где он нуждается. Потом я дам несколько ссылок.
#
# По исследовательскому анализу важно лучше прояснить ситуацию с сезонностями, особенно недельной. Потом важно увидеть, что к концу ряд у нас начинает вести себя не очень хорошо и куда-то ускоряется. Это наши августовские отпуска, у нас по задаче такси около аэропортов, ну там все понятно, что в августе происходит.
#
# Сейчас нужно развести в моделях части исследования моделей и тестирование. Модели сравниваем по качеству на кросс-валидации. Тестовую выборку вообще не трогаем до моента выбора лучшей модели. Затем уже берем и тестируем лучшую модель. Записываем результат.
#
# По кросс-валидации у тебя верно все реализовано, но если остались вопросы, то поясню, в чем отличие временных рядов.
#
# В случае с временным рядом нам нужно задать кросс-валидацию TimeSeriesSplit
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html
#
# В  каждом сплите тестовые индексы должны быть позже по времени, чем обучающие, поэтому перетасовка обычным способом неуместна. Как раз TimeSeriesSplit решает эту проблему.
#
# Схематично работу можно представить вот так:\
# </font>
# ![image.png](https://scikit-learn.org/stable/_images/sphx_glr_plot_cv_indices_013.png)
#
# А по реализации будет очень похоже на обычную кросс-валидацию:
# ```python
# tscv = TimeSeriesSplit(n_splits=5)
# gsearch = GridSearchCV(estimator=model, cv=tscv, param_grid=param_search)
# gsearch.fit(X, y)
# ```
# С cross_val_score() cv=tscv работает также.
#
# ***
#
# По ариме - ну ... тут быстро не разобрать в комментарии.  https://colab.research.google.com/drive/1ldk-Edy1UDv3-SZAr42rRzK6bQ6aLnGJ?usp=sharing - вот здесь можно познакомиться.
#
# По общей проблематике и ариме в частности рекомендую вот здесь подсмотреть лекцию:  https://www.youtube.com/watch?v=RdTxLXmbvjY  ( могу выдать быстрый ВПН на месяц, раз уж предлагаю ютьюб, мой телеграм @kriill )
#
# https://www.youtube.com/watch?v=u433nrxdf5k  - вот эта лекция очень доступная и хорошая.
#
# Ну и среди подходов к прогнозированию, раз уж упомянули ML, экспоненциальное сглаживание, профет и ариму, то можно еще посмотреть про ряды Фурье https://habr.com/ru/companies/glowbyte/articles/542940/

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Здесь также можно было бы добавить проверку модели на адекватность. В случае с временными рядами модель будет предсказывать следующее значение предыдущим:
#
#
# `pred_previous = target_test.shift()
# pred_previous.iloc[0] = target_train.iloc[-1]`
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проверке**
#
# У тебя получился хороший проект. Неплохой выбор моделей для обучения, достаточно подробная исследовательская часть. Однако есть и что доработать:
#
# * Важно изучить сезонности и на основе анализа ряда создать только нужные нам признаки.
# * Необходимо разделить части с подбором моделей и гиперпараметров от части тестирования.
# * В профете важно поправить ошибку с вычислением метрик.
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Комментарий ко второй проверке**
#
# Спасибо за качественную доработку. Практически все верно. Однако еще кое-что осталось.
#
# Важно устранить утечку таргета, убираем признак mean.
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉
# </div>
